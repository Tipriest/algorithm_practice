# %% [markdown]
# ### 生成YOLO数据集标注

# %%
import shutil
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import json
import glob
import cv2
BASE_DATA_PATH = "/home/tipriest/data/seg_risky"

training_anno = pd.read_csv(
    'http://mirror.coggle.club/seg_risky_training_anno.csv')

train_jpgs = [x.replace('/home/tipriest/data/seg_risky/', '')
              for x in glob.glob(os.path.join(BASE_DATA_PATH, '4/*.jpg'))]
training_anno = training_anno[training_anno['Path'].isin(train_jpgs)]
training_anno['Polygons'] = training_anno['Polygons'].apply(json.loads)

# 生成训练集
yolo_seg_dataset_path = os.path.join(BASE_DATA_PATH, "datasetBaseDetr")
yolo_seg_dataset_train_path = os.path.join(yolo_seg_dataset_path, "train/")
yolo_seg_dataset_valid_path = os.path.join(yolo_seg_dataset_path, "valid/")


def normalize_polygon(polygon, img_width, img_height):
    return [(x / img_width, y / img_height) for x, y in polygon]


def create_classes_file(folder_path):
    # 定义 classes.txt 文件的路径
    classes_file_path = os.path.join(folder_path, 'classes.txt')
    class_list = ['cat', 'dog', 'bird']
    # 将类别写入 classes.txt 文件
    with open(classes_file_path, 'w') as file:
        for class_name in class_list:
            file.write(class_name + '\n')

if os.path.exists(yolo_seg_dataset_path):
    shutil.rmtree(yolo_seg_dataset_path)
os.makedirs(yolo_seg_dataset_train_path)
os.makedirs(yolo_seg_dataset_valid_path)

# 生成训练集
create_classes_file(yolo_seg_dataset_train_path)
for row in training_anno.iloc[1000:11000].iterrows():
    shutil.copy(os.path.join(
        BASE_DATA_PATH, row[1].Path), yolo_seg_dataset_train_path)
    img = cv2.imread(os.path.join(BASE_DATA_PATH, row[1].Path))
    img_height, img_width = img.shape[:2]
    txt_filename = os.path.join(
        yolo_seg_dataset_train_path + row[1].Path.split('/')[-1][:-4] + '.txt')
    with open(txt_filename, 'w') as up:
        for polygon in row[1].Polygons:
            normalized_polygon = normalize_polygon(
                polygon, img_width, img_height)
            normalized_coords = ' '.join(
                [f'{coord[0]:.3f} {coord[1]:.3f}' for coord in normalized_polygon])
            up.write(f'0 {normalized_coords}\n')

# 生成验证集
create_classes_file(yolo_seg_dataset_valid_path)
for row in training_anno.iloc[:1000].iterrows():
    shutil.copy(os.path.join(
        BASE_DATA_PATH, row[1].Path), yolo_seg_dataset_valid_path)

    img = cv2.imread(os.path.join(BASE_DATA_PATH, row[1].Path))
    img_height, img_width = img.shape[:2]
    txt_filename = os.path.join(
        yolo_seg_dataset_valid_path + row[1].Path.split('/')[-1][:-4] + '.txt')
    with open(txt_filename, 'w') as up:
        for polygon in row[1].Polygons:
            normalized_polygon = normalize_polygon(
                polygon, img_width, img_height)
            normalized_coords = ' '.join(
                [f'{coord[0]:.3f} {coord[1]:.3f}' for coord in normalized_polygon])
            up.write(f'0 {normalized_coords}\n')

# %% [markdown]
# ### 从YOLO数据集标注生成COCO数据集标注

# %%
import json
import os
from PIL import Image

def yolo_polygon_to_coco_bbox(polygon_points, img_width, img_height):
    """将 YOLO 多边形格式转换为 COCO 格式的外接矩形边界框"""
    x_coords = [point[0] * img_width for point in polygon_points]
    y_coords = [point[1] * img_height for point in polygon_points]
    x_min = min(x_coords)
    y_min = min(y_coords)
    width = max(x_coords) - x_min
    height = max(y_coords) - y_min
    return [x_min, y_min, width, height]

def convert_yolo_polygon_to_coco(yolo_folder, output_file):
    images = []
    annotations = []
    categories = []

    # 假设类别信息存储在一个类别文件中
    with open(os.path.join(yolo_folder, "classes.txt"), 'r') as f:
        category_names = [line.strip() for line in f.readlines()]

    for category_id, category_name in enumerate(category_names):
        categories.append({
            "id": category_id,
            "name": category_name,
            "supercategory": "none"
        })

    annotation_id = 0
    img_id = 0

    for filename in os.listdir(yolo_folder):
        if filename.endswith('.txt') and filename != 'classes.txt':
            # 处理标签文件
            label_path = os.path.join(yolo_folder, filename)
            img_filename = filename.replace('.txt', '.jpg')
            img_path = os.path.join(yolo_folder, img_filename)

            # 确保对应的图像文件存在
            if not os.path.exists(img_path):
                continue

            img = Image.open(img_path)
            img_width, img_height = img.size

            images.append({
                "id": img_id,
                "file_name": img_filename,
                "width": img_width,
                "height": img_height
            })

            with open(label_path, 'r') as f:
                for line in f.readlines():
                    label_info = line.strip().split()
                    category_id = int(label_info[0])
                    polygon_coords = list(map(float, label_info[1:]))
                    polygon_points = [(polygon_coords[i], polygon_coords[i + 1]) for i in range(0, len(polygon_coords), 2)]

                    # 计算 COCO 格式的 bbox
                    coco_bbox = yolo_polygon_to_coco_bbox(polygon_points, img_width, img_height)
                    # 将多边形顶点转换为 COCO 格式的 segmentation
                    segmentation = [coord * img_width if i % 2 == 0 else coord * img_height for i, coord in enumerate(polygon_coords)]

                    annotations.append({
                        "id": annotation_id,
                        "image_id": img_id,
                        "category_id": category_id,
                        "segmentation": [segmentation],
                        "bbox": coco_bbox,
                        "area": coco_bbox[2] * coco_bbox[3],
                        "iscrowd": 0
                    })
                    annotation_id += 1

            img_id += 1

    coco_format = {
        "images": images,
        "annotations": annotations,
        "categories": categories
    }

    with open(output_file, 'w') as f:
        json.dump(coco_format, f, indent=4)

# 使用示例
yolo_train_folder = '/home/tipriest/data/seg_risky/datasetCOCO/train'
yolo_valid_folder = '/home/tipriest/data/seg_risky/datasetCOCO/valid'
coco_train_file = '/home/tipriest/data/seg_risky/datasetCOCO/train/train_annotations.json'
coco_valid_file = '/home/tipriest/data/seg_risky/datasetCOCO/valid/valid_annotations.json'
convert_yolo_polygon_to_coco(yolo_train_folder, coco_train_file)
convert_yolo_polygon_to_coco(yolo_valid_folder, coco_valid_file)

# %% [markdown]
# ### 删除文件夹中的YOLO标注

# %%
import os
import glob

def delete_txt_files(folder_path):
    # 获取文件夹中所有后缀为 .txt 的文件
    txt_files = glob.glob(os.path.join(folder_path, '*.txt'))

    for file_path in txt_files:
        try:
            os.remove(file_path)
            print(f"已删除文件: {file_path}")
        except Exception as e:
            print(f"删除文件失败: {file_path}，错误信息: {e}")

# 使用示例
delete_txt_files(yolo_train_folder)
delete_txt_files(yolo_valid_folder)
# Out:
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/47ff59ecaa028ebf74348f534f20569c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/465eed279eb4d90338e5978ed0731de6.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/415ac15767f349fce946b6bfab90747d.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/409f2f6ea591f61939d72cd448921254.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4a43dcbdb8760eef02cfaf288c5a053f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4f014e167b7408ad6c5f90675962a025.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/464fbf33102ba21c327c4c51808108f0.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4ed64252d4fade5ff110f8178f9600b1.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4484b746ea442d55f9e582de44ef7dc1.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4bbe5aa19923e36f615e650e5d4ba1b2.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4e4d59ad500e69df7fa5f1549c599d5f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/43172744e1cc06c7550d08dfbe93a032.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/444fed26b9550813cc620e049823aeed.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/49a280c0d975dcc4ddd9114c2217a333.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4a6fb1ed21b7d74ed73a69d616bcc990.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/44975a2a40c3f86d54e14fa78d0ca01d.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/49777846e1a61662f4bf67d4aaf1e695.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/440f9b94063a2c1cb15b29da2cc50a5d.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4f39a064a15b2f79b2a7573b43e89a1b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4f6192188fdf0a1566b4f7b9becb5016.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4ea46847b9137d7159aa49436e59e513.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/43619a6dc8bcf278bdd31bf337e186ce.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/41046b0373a27026951a67b46d9cc9e4.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/41e6bad89707a1d1713d4da7c46492dc.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/477997f10be09ab1616fb4d559427e6c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/461dbe2c212cfead9013be36aadddba1.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/44196eb7ce299ac451cbfc157192f89b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/431762347867a5b1b4039c4d14358ccf.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/48b0593d137d7039efa3e48346a27549.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/414c9e097e5a1d26e51ab4197141dcb2.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4b95855af4ea88b5462e640d7f197d24.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4a7114d5f9f502cfa4bc9b1cedfcd1be.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/42858bfb01c12b0b537423be986e47ac.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/460b3a5ec6e40d9cca290e9bf3c3b379.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4bceee3f515096e1f00228f19c216d8c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4aa45d53f952f1deac8ca4241a45b068.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4bfd4b28dd87051350714444a13b6643.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/494fb22d02c6492b3fbb61a746dd1ef2.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/496e549f9f268b5b56f644fedb89f6a2.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4d30bd283da22203473e661bc3d00d00.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4e1c55cd14272341add0c577aae6c9a4.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/426ee95642e17905f4e3f9a72751b20b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/42e5df3809a9a7392c58a022931700c7.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4d6c2f3120390acf9f5f77eeb3c74ff6.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4d98a6cd109a0bc5b8d6af3b3ce0cc0e.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/498fa8c279e12e55fa4fc3d31daa9f63.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4bcf2bbd96fc7efd45ce9726c166cd90.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/42131c6fbdaf06c0be30937ab46cb7e4.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/473b8b09f5e35c5a03f1d9710130c0f7.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4e2875575997ea006bc4da2480f9aac1.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4fbdd7d718b21437dc66523f26e04320.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4ee49551e97f7dbfb386c311853901c7.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/43d62e946ff6ef93d5f371241070b859.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4fb81290f261baacd77e6592db92099c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4e37c03a2e7386204e51d121185189ed.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/417c057fa2c7d6a10900c5c999d0add9.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4c698c0db515b8143f645397dcaf7653.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4e8b42cbd1aec6d04888d1cf42552428.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4403bc179ced9c077c17b8907a8ed919.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4dc1a14dda7d4c69ec2cc6fbbf639872.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4f5c4d86771d855e809fbbd5ecbc574a.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/48b715802ab90bd6b4b8762f6aa1c9dd.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/43f93e381f703b50d08104c45d414e61.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4bd88f006251896f4bfa8c719e146091.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4229be86b0f361baa41de0c94ab6ece6.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/41bb2da5e40f94d560835ab9ac0bf1be.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4c8629e55b32fab8026c95d89d6be8d3.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4579e3d5305b6c90e792e6f2c74cc0c3.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4c325cea3f73ca9c92ded0eb58709a17.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/45f8e72b50bb5c572307119775deacf6.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4ef1a2be0b9a948c8efaf9f488b8fa60.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4e84a7ef433346c03aa6c77c6efdb8fe.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4d7780d6f3552e837244ff3d349d7fa5.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/478a02c94874469eba3875dda5a87a99.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4d54ab9fd9c53325f61138ea9cfecfd3.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4863fc389bbf07707c022818d940a9e5.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4581f58c5b9d76ba1c113667eeaa1e81.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4c050d0d51ee98f14b739ceaaacb06cb.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4df3a66767a1e99cea3f94e7bd36ec62.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4c28356bda2940f41f228195ce759b6f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4f1c2876e7c8a4b30586259c6df08194.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/48560da6c8a657ffa5ad4d33a267e1dd.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4c8d54c2e8b83e3716915e4163ca5384.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/49108072cbb37d6ef30a03c6978d1a5c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/451c79a9124ed39c666d834c9a1222ba.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/41aa99a519a0871999cba1c74cbf1ead.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4af34dc1f21272c70c13e0507c67612d.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4b3e4536529026ae715906bf7c7e79de.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4a65a23294a08404765eb8bec1730e52.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4bda3275635d26e459ca6f7237162d5b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/42d64ee9f24cb4ad87027dd1a7055651.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4a06d0e6a9f8470d35a98f703263c5a2.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/45170ac9566c865cddb08c43b357348c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/482d39221a673bc51c4bc15b46f98e6b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/497b65ed5167e052fce99c7619c05fcb.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4ae5b9f4ef5b0f423da39f562401caed.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/436c616ae57870eb363155a6f15d2e38.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/42820276150411e467fa4b5eaf931d0c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/441c0296fbe0b2553194524dc6b02629.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/455a939b72ae447c1f6d10cab9419acb.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4be5df40b281ad60ce44560b2a9c6839.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/40c49c1b14bf04eecf9b4ad6bf896281.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/46b669c3a3748582de73c322caef2e3e.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4a0240ac563edb3a69bfdf01274e9f96.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/42b27140344424d3798c85e2283ae394.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4813375a227a9752e8296f44df069706.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4eede107656dced82d07587de2db0068.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4406ef9f6767355a065b8a2f30033b0e.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4c21d5ff86716041fab8ebc6a06ebac9.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4fbf3b8b769a3a879d75a73b98b186ad.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4554d165652a5d5e52897f9b6be84353.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/408da6ded730be6f92b1003c92e7a89a.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/476d3aa520eec87887816095949cbc1f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/44fdd89ab08da488718bb673c7cd5a02.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/413f4d7f543544d6e3bc9ea68fc11b20.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/46528934e29eca18557fd0860aef1608.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/400c59579a59f7d0312c79a3add65d62.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4838de93b29ca7b172f2df5c0e6df3c0.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4ab59253fef94232b8b90d7d9408ff0b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/46d543f6614244790610a708583a9e40.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/403deb4a56f665a4fd8c0a5bb340d3c5.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4bcc958d9f0c5bb24b251eb26e062fac.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/409dbb188886c51e70057f7f38482a08.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/49abfcbb407f41322a4a9ee0a6ace9bb.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/41bbab649a6924d7e59dad7ccbb9f3b1.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/431726344d2c264e2b32d8b9bbfcf749.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4fa939ba22bfbad4c7c76d2d0ce8ebb8.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4bb03bac4c1db9f080c4c2bb7161acd9.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4d1567a91a0f48d4b8e95cd815778e4b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/43344590187a860a74725f33e601b16c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4a96aa8c50145f3d3009baa4f3296559.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/422a2a02f382018701e311f9522e0df5.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4a2706547df54eb907981f22610e25ef.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4f1bf9489d758f0aa77d333747323271.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4138881705e84314272cd9d1a30a934a.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4bc3a01541cb9c124ceae71139a5e19f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/44dc457bf7d6a26831352991ffd6b824.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/42056704c08e5be1e73ade5ffd253c75.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/474311028a58c3a29dc8302470a2844a.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4b5389cd59f82b9ce5afa62d4cf1d624.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4cccb17f9842973684d32c007c1fcca2.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4419feb67fd08074b0b90995ad152b59.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4676d4dcd72f2684742b1e04031cff06.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4c343bfc7ebc706f76bcd31101852663.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/493e4a33f576098b8ab70bd49c0b4943.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4bdd929f851a04041aa76c624387a14d.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4aa462f5f11c0792593f1e0dccb184d9.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/435a3eb0432f253693384fe6bffd7e4c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4ed7d3e2babac87bd169de766e0ee92c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4166c46d82923acd3a979526b904d3f9.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/43d7d04a7002363bbb6586f344e9fdb2.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/465f2f1ee3752bc59ceb8edc7f08e2f2.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4c89f8691897db99984c6b334489dd9f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/47032045a56faa18a3f584705f3ddfef.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/40fa762366b41436f55929931a6e27a9.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/447c61879fd92f5bb1d4ac5205ede542.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/46ca8fec4a4c46830f296d6ea6b7ab1f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/46aeb3c186bc9328e2586963c4d3c5fc.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/43c6c7ea597a1684d1446eddab7c1298.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/48d0fa52573106417a53cedcf14d290e.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4b645c7ca0f9ff91da2c5a7a0a99e751.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/466fc4eeb653232891389077747249d9.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4a8fdd3be5f9030a575f08e4494b561b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4cbb170c8c4c56948b72fcb38e0fda76.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4031c2627039127f10461ee4b83792df.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4b9ca7168bc6bc2fd9875f32ff059590.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/491c8931dfbbc5a4ad85182c7efdc9b0.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4aca4760a867b650492d09b915ab4b92.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4f4bafede687a2f0792b3e082b85498a.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4f98184b1a491f2df3340d006a5b28c4.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/430c59f66aece8985182db58ed474c93.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4a316c31f64bb98bbdc2b1bf5203095b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/439cf06437d82208553a6d32116d2ebc.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4809fecd22d154518b528b01b7f8d567.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4dd54e953b9cb9b9bccd0da747986342.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/44ed3fb2d8ac94c9c6dd3ba804c0bfb4.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/46ef81a6b4ce7e5db7db05c57acec587.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/42419083ac31fb163102b61f3d547eed.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4d0ae7bd5a5b76cfd3751a15ef65ca7e.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4bbc514d21f836caa509b7e8b3604ae0.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4be5646c564f56502021759f704f137f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4e1a72c82126dca9e2610bc29eeaa632.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4a2f00558aeea8d46e2bc799085f7856.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/438bdd4bb641af15a320462019ad28a7.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4bc93643aacb1771426c46633381506f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4c1d9a63dcb0cdf00e9efdec0aeba8e1.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4e9f90bdaddbfe20565f25d16cff6b62.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/446d98f920ff09428a0a2d043a9b8d8d.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/48fffe6106827269518231a704571167.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/44e4f44d000e99aef5dde00ecba40170.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4640e5e11b8553643a6b907671d29dc0.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4a1cf14fc04cac595945a53df1a7478c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/455e8a6fc034c784c94103916f213255.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4b14c999471fe456927a13c9e8bef531.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/479b5776f3358804a73721ff7fe87925.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4958cbe2d9dce2eefffba44e8fde4cf3.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/45c48793086b25b6c125574370e4649a.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/46c8929adef9231f1e54ff5348441df7.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4be4483859c52ab03255cfed09bfe6fa.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4a5e412c44270c9061d93f4c420441a8.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/429086587da2c5081a46aa8ae8ee1d6d.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4a64b672cb31e1222d8339380cdb1cc2.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/49e6635beb9ae3019df7c8ea3c096d64.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4187aa1453c38b67ae34c9ffefd4877c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4bd8210969647fd17a45dc7342a3e63d.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/469ca5a544fad798b2fecfc44ad75782.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/44acfd32520b91030d09b49fe8ffcbbb.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4ea972498321fb066fb8cf081fb325d6.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/437b6771aaa55633da8cad5b597b9caf.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/490a0d39c1749942aa9aba322d71aa65.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/486cef8799bcdac73ecba2c4c7147727.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/46172f557f8121508559ac0b3f5ce8a4.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/422440674d00b0542f8edb8b8b404195.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/47905336b35365369778aba54cda56bb.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/485cfc6912449160c75a9a1e827a14e2.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/48251fbf2a1ffceccb266e8c3b976a22.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/47d9d93461ae123245c40247b158cf00.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/48a31f6c1af9c6298e308eacf6a51f27.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/481c463d74ff383987c41dc06d390076.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/46ca1124d0931cc0c205a5fd0e259feb.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4624870529bdfadca8103f877717849f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/42bfe5422e7864fe4d5cd0e39592b47b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/433fc5becabfacf28e34f644c8431119.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4f73c6f3c54ead2f8a15728bb4704077.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4138e5c096ef3e6fe81a7ad2249951ed.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4d0ad6a53351e3d4321acf398d85daaa.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/40616ca010135a3282396a7e2afe87c8.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4655c192cb021c3cb58e38176bc54042.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/461f5b162f1abced2e2952ebd740cf58.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4b4cc2abcb9f36336580155f0468598f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/492010d909f19aa534f35232395d6cb5.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/43b4fae1efc9712d553d93f66fc65b69.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4d2881d33bef9c804817a3fb1d90c272.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4a1fa8629cc858ba349abd2cc09936b1.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/412cf8a5ada5e394c23ac3a2845f57a4.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4851cc67574e0098f3ed2478dd6ee380.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/404b8ea155eaba69912567d283c94bad.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/47ff3246f95f51b399378061e760bec5.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4b9d0e89755482ae26036c3590396348.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/403cac2200eeb86d8c726ea918f7933c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4224b4c024c324c7992d34ddb3081c3e.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/495c13c111786c52713b93d3fb42d575.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4968bb16e90c15dfa67f9a29be61a13c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4e8e014e088c5d215abc432837d71bae.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/456f6a6c88025b51e3682026d38ae977.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4c5ad457fec89ed1b2106df58ca86bd3.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4c3bc820d550404c1504e795a23b3944.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/41791c08aa43052837876e77ee8ae8d3.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/468053ef811fefc8db6479cb5dd41c93.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4cfe1b238f1ae6d7a00d14e64c9a9647.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/43480bd79486d5380fbff67edb8a8219.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/459a3e34815736ef91798f379d1e788c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/40d7b45ebc1de231fc6cccda42428681.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/445baea1a094a7a8582f73cb5aec8fb6.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4dab5c1fffd04286b1c9c44f70953f6e.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4a222ad315a8009e3ca22c5da278464a.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4ecd05f5498e558e9bf5ad0d8eb4d131.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4f4a6bde1ffc1c8a091f01469507ab03.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/416fa601a1e6928ec2c8452993a51cab.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4fa25a3b6279e40f947e03a2ebce542a.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4080e49a5782c2cebbf7e158fb10dcbb.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4290e6c81e31d4f41fc93b8e3caa97dc.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/425a4286faf1d0d4e3d4f4e832c4deff.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/46d473b73e4f8dd773015161e794c80f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4c066ba391251096bca8b80026883996.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/485c792c8a94c43287fd5443d7098ea7.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4a894305e06eefe298b96d47396936c2.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4b300899f35136ed4d8489b16c59803f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4d170e4c4b43924e7b98a36c3f256b2b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/43e8389f48b73765691e7533c6948e88.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4709fedce5f9f91e5eecfbaf1021a634.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4be5284ae60c2bd553b0250a5f1fa419.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4fee5566b3ac6a464d722e7539c0192d.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/442ffdfde8aa1ad1f358294ef8a44052.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/475ee92e3d1d317ea10a3df773563f1e.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/41a43c9df12e384759e8e605fc0e3bba.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4069e65ce4d1fbb1a628914dfd657918.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4fa2f085ed8f87484627935195c3d6de.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4e83ea2023bd4e67eb127250225a6ef9.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/477a55896a4e8959812257a0bab4d068.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4ee44cb6f9236eb5ca63807196abbd7b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4f0835d7b22367e361f9dbb28e53243e.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/422e758a469c2475c80605f90184d349.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/437ff07107665af6568461a1323d032e.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/419d39fb63340f4ec98498fd7bc71c60.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4614ad2a44b20b3317cbb4aa276cd850.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4351d40972eafb3f129222a17d4148b4.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4bb0f1fe44562e0ad9129df85c7a9346.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4cc7e07ad43d534971d99b01473ca214.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4557c23929786ef0f32bfaaae2d5dc51.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/47f9f06b0200eff78b7e70cf6747a28a.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4b9fc6cf19e5ef540cad6b68494fabac.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/44e54f4da5df9848d63ab52949bd5356.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4820706d2d7000fe4732f309d4d6bcb6.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/46088934410c6a7714dfaadcbdac74ad.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4a046a064ea6128d40ee4312f33970a6.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/40d6b71a097942238384d9f19082606e.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/41550b3e51fcdc58ab4ca09b59188ce5.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4742fabbdd666fb40e2c3a1df244d02e.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/46ba98edcf75b7973f7669376b154926.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/462f188dae77dabbd200d310246a3914.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/485ee3e97097bd9cb79c89e823f3212d.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4bd57675aaaf8fe2958232a709bdf548.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/41d27fb02910aec21651abd23f400979.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/414ece13364cae4d8963b1022cd2eb63.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4fba4372f6dca1a8a6cebd81a2684ced.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4e35821177e087de2ad7341d01251bc3.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4d72e32d70de52372d444071ef0219d4.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/440206ec8de3cda0af3c3b7fd8eea4e9.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/450d61b00016724ade7f2fbb3f0addc8.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4257bb4ec74cc3ecc6ab64e2d5d50bce.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4ef9bbd7e6183eb60f84dcaca5385c19.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4d2c964adf7c7d2dc08314681911ac0b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/43f105ef55461a64ebeb3faf4e31a3ff.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4b2ccdd55c49b6bf7e46237fd4b78d90.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4484c4a6f1ebd92c30232377f7cfd6b9.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4dd817e12872e8b64a1395be57229507.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/47a92ac112ef18bd7445a476fea2d8c5.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/45ac39da087fc4a4f9e314658f1d26d2.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/424a37bbb711fa7b49e3b061b956aaac.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/45b98463918c3ebc7dd403306fc07ccd.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/44ebaddc0200c1378f71a13421e53d19.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4e880c1ba8d425abd2b4b5069e36547a.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4809a773cb30c7116617815a2b890213.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4e01e6e5a3ae4d3200c1b98afa3a495e.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/493dedc54a7124cf3f29b8547f342d1b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/423532b119292f2a0d90890bc3acc00b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/49d222112e5c101be68a254b4c14907c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/430aae299806d67886c0dc3153e137d0.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4561ea0094384a50eca6fdb0ba54ecc4.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4baf60bf7276acdce02f27adf2846065.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/49fdec18fc09ffca1adc9cff8d5a7bc5.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/45c9a0f2df1354e58ae6403a26bfb17a.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4b4d4c5b35f3e3203ac2342fafffa46f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/49dcbe4c030f90941554c7298866d77a.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4388228d244f9846140b16a675202ce5.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/412eda4932909b4293a63b6c4f34f58a.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4bf4ff9ab005ab2b3352ec3978a74048.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/459b20d23ef8a939244f80fd33a2b84e.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/450d4c5efdfdee6702d346bcc6f38bd9.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4c61cd9a852447d1c9215ace7d28f1b5.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4264548d6695c389e1ff8d056f2eab57.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4ff0b79e949a774aedf397144e9ea3ce.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/41b468b2869ad19e71634c4c2e674fca.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4062da40337479c6f8ebd366cc2eb0cc.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4e494e434ca0a51638941e376ae1c59b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/455a32e09c5c62955dcf0211ba297174.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/47cece947045dae2b29fe0f0120b1dd3.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/43f6a94d183f969ef494610a21db2563.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/49721cb4755652f7c04330f1f95a5bac.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4791dd969a6e54c60b696b107b464dc8.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4a756d0a67fc10584ad8e6fe0e265c55.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4d4b7fec1f2751c8adc2d18e7ce335a4.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/42f92ca188b9de2ecd20591537317274.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/42cf431d598857d1720755d08f3d99c5.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/445178d4d69ed65b300a34691a85a3c5.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/47a13ae10d40bbcce7c08e2fd5e1062c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4193ac5a9e374ecca51f4e19aa6d4e62.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/46f29e9c202d4b9ae007d85354fccd67.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4d31f8a4c9e9b6627b517b3d35923016.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/487f1a39c8957aa53fe09ed1d0fd63a2.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4130e86cc27a26de73a02f63f8815926.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4370e851e9ca2571796eefa07fd4bf05.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/46e78b708b4efe6c3f550c1199f93d4f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4d2b1509611ad9ebe755b8e6ec2c7968.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4475c64bb865b1aebfcef89e9eef2359.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/425d79d6908da14b94f6d0e172e4cccd.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4d0e48689249b27374c9060dbf8acfc0.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4fa4aebd87c8f8311cd922d94181528c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4855ad819532ddfd3b944a521641c218.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/40c5dda2ec92ded3e42ef0454800292c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/406d0e5e876e6206ef12c6d5ddaae686.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/42a2947a8c919f78f7840afe4a5681db.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/486ceb5b854db2b19971c8568dd0642b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/43c2104e52ea11c1fbfdaf72adfcce87.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/426eada51ba02c5a7968eee9b09f4077.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/45c0813cae0b37860238d23b6a3cfe38.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4d4d1028c0ba427a16e09ee997ff8ace.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/49649ce383fb409288fe780b04e17694.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4cc1e17d0eb105c6340de99aff7b6de5.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/40537d9d44250d2cb75a560778d9abd8.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4afb0e6efa2cf558be28422fa8080f73.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4683fc98c0eb7aed6b42cf3e94275548.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4e9b0d8c7586c9e1d86565af629df786.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4f207e3834b17e69f855d288658dba1c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4843ea9a11ec50be17550f11efce8f40.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/46a5098540fdce929cad3ffcd54a6270.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/46e897a49f2067e0794ba480843335bb.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4fb38cd523f4c66ad8047904846ed3dd.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4027ae89714732feab3460b7095df950.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/42f831ddf65d587dce07528c09174613.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/48e99df0cf6f2d53dbd9bc44621e6d2c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/43d912146920da7943b7247bf2761401.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4972f9c03946459c3d4520fcd352e3c3.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4eecc5ad95ee4166fcfc6777d03c8937.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4450873fc58c77814c7efa0bb60950f9.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4a7a662647684b141061296944e7b2c6.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/48a6e3649d0cf9af28bad82e9f8dfda7.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4b9aa40734e1f0a66cb0565d804537a9.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4a9338e98f6d0aecbaf5ebcdd7be0352.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4eb48f607b93480e55c8b26edc13a195.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/45256792adc4120bef972dc1930495fa.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4eb781823dc6e95ceb207027a737f156.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4bd412be5bd7ce200d71ca6c8dbd1b69.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4620f9836c747d6829754071d9d5ddc1.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/414324402caa48ef07ba427694aeccff.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/428907b91a3392533b156b3165f1774b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/41b50f00b3bf9022bc6835f73c0a16f0.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4f3f1d29481e6f727042066a9c3e253e.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4696bfbe56d597c82753eca3a512e61b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4a8f4e5249d73fdcf25b5356155f7bf6.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/42e1f31c9281f8694f22ee5315e90f56.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/47151f6a7f8f26263edf90d107e4f8ff.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4affe4a6adb3d95f1264ffb227c32f0b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4fbeb9bf98c441c209130e397c8a54da.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/48c96c2e7de77c2f8a3ffa2e04010a8b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4ccd776b79a6496fbdf0e7769dc94d0d.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/40c0632917075f276488c50a2265a612.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/44c310a2950abdb40a40a3eb1b310128.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4e91a14b81c0a594abf4810da6c14226.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/456cae54d6bdc0902a8b5cc1586285f2.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/405334c1c1a00cc60536b9eb29774f36.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/418d29478c73927c5752665679675643.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4418462ec663aa79b3c8362d9e0baddd.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4c01dfc73ef01a83ee157a0a6f9d13e2.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/46ef1aaa39119dd23e9e12378dd1bceb.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/42806f1a12de4b69b35ba100a8b51c4f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/44d28f8f231f261763e36e3d5f00a154.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4da9d83b08cb809747c0c171600590ac.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/41f060a9562d0d7bc09de937315d0b06.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4962716b8f3efd6ff1d4a030e78ae636.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4e6bdb4ad3945f97705cf13a655b5ac1.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4ad85b0ecab9c5587eb77e8c202c3f84.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4e52d5283162a43111ea004fff60c170.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4596c7c1a52699bc2b39823a011e2df9.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/46077b352e724f5b589802e5de2b99c7.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4b5f44de1d2131320e98ebbd916c005e.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4566bbaf84820ccc8b69db79a7a60732.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4826808e94492d723d64800e59e95ed2.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4c488bfff6318abffb5ea166e26c574a.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/48b812edea15ed7bcd996adc7bb9e5ca.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/446f186635b9ce2c110312153ab906e0.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4467a9631b79c3d2c8c7d3cc2ed0be59.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/49854065ca218d09d23a5669958a472a.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/45894d0c01ac2ccaaac74a2ad3c2e7a6.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/43f852ee7907e808854cb5457532e1e5.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4eb77930650805d01c0c6c0d93d423f5.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4581246b0ddba098d533a8ba87bd6b85.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/489e7f243aa2183d33ef4955e0e0e754.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/42047c353a75042043a81a232822ec95.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4fe62cae5ce49f661a96018e50e659bb.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/41d7c16961a01f0565ff2e6e204983df.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4ec4ef8533528784acd3f11dddeb4049.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4e6625af9207812daa36a4a92212fe6c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4ce169106b0f59ea0c57df14e64cc0d9.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4a429cf74b7fe7de5e205980fa022bf5.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4951acb05049f0c6ce0bf35a96ba2964.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/48231ba5cca24e308c26a552ae92fa22.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/46eb614367c4662deee003d2271b71c7.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4d211e767bc1828661f274e7eb198bbc.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4680ad9a2c887589b6ab10ba2128902b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/47220f4bd33676f765fae6ad6663d8c2.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4c2c34e917279ffdeab37d89a859f56b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4961320d9b443bbf8e5de718813654bd.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4288eb52f57740a7e15115348ede32b1.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4e41c933f3d191bbe5e0146559f9b3b9.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4750cce5bd9fe1ebf0dc4af27d0935ab.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/40e41efa1464b17f0addf1f86baf0b46.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/42a76afa2e092db2f9078c3d18663834.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4ee45ffdc1def6806fa091ba0a310b16.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/42b03759944000a36f04b473175aa97a.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/44ff1b4a19a77ce1e649143e5f5aca4f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4f80dcbe44a138d78340a626380b95a6.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4495e8e8b58af6272b5a1f4bcbd2b2f7.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4b338ac74ce171ddcf00db46b3f9a447.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4200a6b66a09e07dd36bb012bae93825.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4276f6d9c2f4c49037dd8b54f5e65e5e.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/438480fd252824598cc57d52042597f7.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/499e9ca7329149957416a1522a5ce6cb.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/48d942a7e39141fb0789e0af838e2958.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/43bb4912865347a70c26e40976a2bc4f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4ab3acbd7c37a2a33139e9d304b1861b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/40b0ec779693f9873333d8f2649aecc5.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/42a9302792b23280800336e2a2b13c18.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/40728cbc76746d42012f933d8e6f6ed1.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/426146b7f266cdb9912d5074c18d9a00.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/42c8632386e1d76e09925e255bcb13b7.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4fc643361e3e63e3e53c6041bc2dd753.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/41c97566e63528ec5b78c37a1719d01d.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/46c3917ae19a77d40b956be1a2fb6557.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4ba91e2d6e40b4079fb0ca9dcbd09ec8.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4b1f4c9e6bc4292c48d882ea97d5d0ad.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/439307a9b087ec8e3c1fbeb05b67db6f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/485c48b06c7fbc04e35e66ceb9ceb2a7.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/482d79b64f9d6f282072814dd29c7bad.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4eda614b0f3e4bbed09b91803ff58740.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4efd4563dc5cb990e4812a33859db699.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/45f80df1a6d85d0c97a16ad0d6aa77d4.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/416272714dbd96f77d308821aabee025.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4a28b9a86c7f47e49003602237f223bb.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4de9c9511d2a46e22c22ad69343bb33e.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/48e54a378452ddf50e5d81b5e6c6723c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4e01a26c320da1ca2df4906f6eb8ae66.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4338dddb7dd39fb518907cbdd24ffd8a.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4b616d88900348ceae66b5723c60485d.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/40fbeb193843941405e5cc8a579463fb.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/413f6824a4b1803380ec2f6448d8dd74.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4172d42e5fc1869599f3031708df0123.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/48c0413f8c58f42417050ec767876e8c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/49bbc0653386c0f14ca6c42ba1109705.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4d63e5bf351961f1a9266c4434b4b84b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/46c9b4779675a9b4181d3315a3ede8dd.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4771df22c3fa7e967b8071bbb05cab5f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/49b168ce7c2f25032b5b0c2f847ab5a5.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/42707f946e874a1e7b282f047a8a7f9f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/457f27ab272374e87d33e1bd77f6a754.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/417598d70b29089684401c0e4a900721.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4ffccec6e255cdc6f409e4e8a2136683.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4900325ef5b242f227db1e4e7f39f468.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/47369ee25bc30a275638f32f11cf67e5.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/train/4b956eff491d3011fedb4e631a3571d8.txt
# ...
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/446ff0f6a22df13efe5f1a437e1db637.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/46740040e24d437f9311cf0980e1d0af.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4a99679d0fd886106bc6e60b8e3b3c1c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4fa6e2f764c1b35a333c7a9e85085c2a.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/47c5d8e5ef27432733ac7b08e6035939.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4d614e950251228ec0bd780a16ee8318.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/44355548b82404e01adfbdcab3f8986e.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/448d970e63a66f5d41d159d8b164ed86.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/476a2bb69e9aa943c9cfd398e5c509a6.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/423e2818434c0e3942c6d2246358494f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4116e62ef04b8d1b409c9b860446d6cd.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/43f5d90ce78a398e0c90c29a0c4619e5.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4f2817100e98169284024c05c276b722.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/46fecfa159426e679b868535b68a6a8b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4130f307085f99aeea7cdd7795cdb0ec.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/44a6e2aea38ebcdd2a2ccf298eb4b6e8.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4813e08adf22432c167dca5f7731937a.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/458590491da0686eac80b757af3ca4c8.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4e5dd525dc89909cc74e364679a8d371.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/45dc7145f1f0526e313489e22f6d3189.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/401b3e8eda46e252ae14f230687863e6.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4e198b904577fdebf2b4ff2c476b26cc.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4b5d4697cf789e575f510b7395c43d25.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4afac6bd7a825596981932cd214f1991.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4cd3a5083acfc6b96756ca1ab26741c1.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/43acfec258f3919c404ef1565103145f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4b14daaea5cf2eb04914f53086ecb77c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/42934287caa2540e0c2a738756def0f3.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/48aece422f32e34b0625d34e5ff02365.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4caceadbbc1eb11b0cf18ca294bac69f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/480e3bf23df0afb636355d574522627e.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4ebc4f91c894815246caea3c4ee0330f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/46eb6c1ae2da1f56093230f6e07cf8e3.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4235345c6244ad5401b0156c8fb0c605.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/42ebb5619f7ee09b651632e7a1247ab8.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/48de99ceb584507fe87a44748027fe29.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/447f64d48fecdf67b5cf45722755b535.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/41c5d494d889f21c782828781467c46d.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/441c7b9669b8ec7bb7fbca15f4f42c5c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/43e64a17b20a540929949b47c8c9edd0.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4326c133b9f8252ae3dccd323c3ec587.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4270d0a002fd41306a81c4e5883134fa.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4759d118f41b4e243226c209143fdbcc.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4e263f68c91965de227bca948fd8c6ad.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/49793bd916777138426d45e4a9487c1e.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/47614f4c369911f6e4fef675310bde35.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/41cdc2f27823fe3a0321fb44712e2c3c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/480ad93e28de7c52cdff5e0423c9de12.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4e5bf38fe35e13cbc92d065163aeb301.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4c8c58473f6ed39256e70e7389fd067f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/430f6a719a4eb29280ab6963a8cf1e01.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4243519fd7d4e53ed176f06626b30494.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4654b2b9d2295990199ab25773917437.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4779c73d68f523b54cfe4e1ffe4201b8.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4b856bdc8346de0a0c763296f1a0b1ed.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/43f704be89b34a85cf976d3a7cb2f655.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/43b0deb3406037d5ad9aab90ea68c8bd.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4d2ec1360b4e20338e62c213d4d6aff8.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/473798a13d7751570f6ca99906439d96.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/452f922ad04fb7f7fbae0f75bcb3d2b5.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4664a7ce95ddfa2aae91e47962d65eda.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/433f308548676a2d20df8f1dc4ae8786.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/42af8857cce504d9acde4dc00bbc2e59.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/47c8f215eadcf901b83b66ebdaf91bea.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/479850bddf910e61ad21cefa161a9a5e.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4a8565059fab411ea185b1c2bccc70cd.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/49666b59cfd0868fb4296097da9ce918.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/455d4f70d96b0f668a354d5c70e6c8d8.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4a1dd0e18a83ba0dc4c5dd603712ba9b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/46e3bdc873494e3312a94f3806257823.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/48b93ed5ab42a7a8f491750fc7b0e0f8.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/47811d13a5f267d76eff54f59e80c03a.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4a03c352409a0ec3ea46916a1d030e5e.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4bb0a5ecd490a8ff2068f66207ba2ac5.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/40c7274423c54683f4091cb6ade1a154.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4d5df48683da9d8dab1ce6b47166e814.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4723fd5730f9da582bd3bf2be967834b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/41b51dd27f54c7439e43c835ac4124f1.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/46ce3100a3549c645bb293e93efbe005.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4664fccfb6314860c77c98f6da8241c1.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4d3e14571792e0eb38cf139157dd365a.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/classes.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4d8497c857fcd03fcb84d3bbc04c030f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4998d135181444c7ebfd6215aab68e7e.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/48136010bfc20fa61eda4bdde7949946.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4543b7b4101d3206e6ca20dd6e5c7d00.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4e35fca8a497545b47b2d71b8aedbe31.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/48f9199f8c10cd4072b19f1b442bd850.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4212527ea0c09257ed67cfa20313d08c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4b1b147831cb2d5d0a66395740134fd8.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/48294a402dd3ca698ac0be8a2622de57.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4d7a684b4ab6e4a33cc7eb9fec2afb63.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4f6c9912a94212621234d5c08c5aec91.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4a7e500503fafcfd6bc032e233a4222f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4619e1e4ab8cca1b56ffdd3db957f047.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/40e3c163635cfeeb83134e43cc56007f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/442120cc555d55ee3933b74929da6e09.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4ae69733ffb929bab29bfbaa2fa1f0df.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4a6083bb05c35cc8004fbbb083c69fef.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/415785fae58c9b97d5500741ea74e348.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4aed95aea41201e2050d5fb30a9dae90.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4493002ef5c630483ea18e6d1bc3cca6.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/435ccac3e2e6773cc7862dcf0fb1d65c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4410fc9c2d1982bdbf7dbbda8a9cac6c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/477e1b06fc376e2404403fa9998d446c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4a76654c446f4b479c2b6ca50012e698.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/41df043fff5f2673c5515d2a868683a1.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/43053d3bb09df66579ddee4005b684ca.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4200975f299d3ecde75eecfe79a23431.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/42c688e09dd23deee69524c7f4bc2d5d.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4ffe7c0f35124dff11e36c0001f1d6bb.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/407f3d06894ad36b11d38c642b1fb77b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4511e2866b02bd2316811c323de80427.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/482e6a8fe3a40f73aecf392c3a83e0c4.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/44d8784740310435185e436eba2f1dbc.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4e52d3a76d92aacda163b23c271a8ac6.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/46a8a776c190909a60bad415a314613a.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4207a0af06ff583b022f12a31b1ba60f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4b5fcb53164be70ac9a68dede410bf90.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/465e435553b2939a3c81ee5f0a43553e.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/412fd0b379d1c1d0f1bf201c575801b0.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4cea07b567573de8dfe57db87cbaed74.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/447e53f902f28ae4d1aa49fcb0a0c6b3.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/41a1057296763ce9d887023ce73ca96a.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/45b5a34d922613e2352745303419aa56.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/44412c3167c873e9af35929c7892ca20.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/43b61fe24038cd00f22ec7ccc2f6e400.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/45a55c08c7d372bfeb63cc6f7494fd52.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/43d1b458b7b9c3d6597a856289ab5011.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4fc23b0a15b6fda0e1fc859ac761bdc1.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4d1780c1b6912dfa9aca116a9479a366.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/45287aaa603663f83e80f543df11934f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/49962cd6759f3b2b96e528058c34335c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4e0288d9f93d7dfa8789387a2b1cb8d7.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/49e2c2cc7f6f449952015d480cfa7cd6.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/44f3aa4177a1c2f89a7aa3c792ef4644.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/49a233707d6d2d72d26cd4fd18b9dc6a.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4269c56dc5a023ea561dd6a61173b91b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/476d84599fcdf351076699500a372808.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4d4cee64485aeb3e9837b1639e6b6f12.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/410382f9aaf87219816b8b6c56e0c413.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/40f6b5ec8e20a72e10796782a7567906.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4d961059012a210bf8579f2a5095388f.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/461ee8d4ebf4c793cbe9ca0b19767190.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/43f97bbebd5eb8cbb4f913af9bdfb472.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/453713739e03b91a26aa52de86e8c47c.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/42379e131ec2ebbf6d354a8f783a826d.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/472ba9dd9175533dc948a5f5365103b0.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/45341b41c6dde041472c951da631839d.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/45ee3a6558f5ff4a92210feb84493822.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/42c12d50ddc8a79a308e25599e2a2263.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/43ef3a109871c4d3f6b7b47ca713fafd.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4b0b182ba4564c1ff2ba787b343ce43b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4c99215b95873372cf5d6789ada9eaa5.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/40323a3eec2891cf6d3426d6b256c571.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4d535027fdd320034b4e1c3beb6f7e42.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4e16b603df3786d04e99c4d08368d41b.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4ace5bc27cb8a33d196ef6e3b172b9ff.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/471a4241e046e3d3bb7e87eb3f3e1510.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/41aaa48a79bcaa04a65c4cf6f9be2aa2.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4a75499aa7b980adcd1a05d0a9a49a53.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4974923694ba63959adcb78333a9df78.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/41891f982b0d70c471011146f93906ee.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4fe62b274d2908f0807cde6bb20bbb10.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4c5a2e3c090462720a45e033020e4109.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/48acc807a441cdf394a4c464ef380fa5.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/494e9795a87dd0cc33ee705ffdcc2d07.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/460dd02ad139609e2d2d0aa80ee22378.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4fca0b54709953fa6ac76901e1795f94.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4b266196ca3f92204ed8beeaca82cb78.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4204c20d6ef3c868cbb88d1f2cc857b2.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/45ee5b62f108588f175f2ec0d2db1dbd.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/4f1d2b37b645ad7982e04e54b7519ae4.txt
# 已删除文件: /home/tipriest/data/seg_risky/datasetCOCO/valid/44d44842bbf500acac65c59346a970a3.txt
